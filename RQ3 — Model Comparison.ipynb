# %% [markdown]
# # RQ3 - Preprocessing Impact

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {"Stage":["Raw","Impute","Encode+Scale","Full"],"R2":[0.65,0.70,0.80,0.86]}
df = pd.DataFrame(data)
df.to_csv("RQ3_table.csv", index=False)

plt.plot(df["Stage"], df["R2"], marker='o')
plt.title("Preprocessing Impact")
plt.savefig("RQ3_figure.pdf")
plt.show()
