# %% [markdown]
# # RQ7 - Final Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {"Criteria":["Performance","Interpretability","Robustness","Deployment"],"Score":[0.9,0.5,0.85,0.7]}
df = pd.DataFrame(data)
df.to_csv("RQ7_table.csv", index=False)

plt.plot(df["Criteria"], df["Score"], marker='o')
plt.title("Model Trade-off")
plt.savefig("RQ7_figure.pdf")
plt.show()
